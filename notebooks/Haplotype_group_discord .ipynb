# %%
# %run setup.ipynb
# %matplotlib inline
# Out:
# <style type="text/css">
# .container {
#     width: 100%;
# }
# div#notebook {
#     padding-top: 1em;
# }
# #header-container {
#     display: none;
# }
# #header-bar {
#     display: none;
# }
# #maintoolbar {
#     display: none;
# }
# #menubar-container {
#     position: fixed;
#     margin-top: 0;
# }
# #site {
#     height: auto !important;
# }
# </style>

# %%
#load the hierarchical membership generated by our notebook in this repository
hier_group_vgsc = np.load('../data/vgsc_cluster_membership.npy')
np.unique(hier_group_vgsc)
# Out:
# array([b'', b'F1', b'F2', b'F3', b'F4', b'F5', b'S1', b'S2', b'S3', b'S4',
#        b'S5'],
#       dtype='|S2')

# %%
hier_group_vgsc.shape
# Out:
# (1530,)

# %%
#compare this membership with that from the phase 1 paper repository

# %%
hier_group_paper = np.load('../data/vgsc_cluster_membership_paper.npy')
np.unique(hier_group_paper)
# Out:
# array([b'', b'F1', b'F2', b'F3', b'F4', b'F5', b'S1', b'S2', b'S3', b'S4',
#        b'S5'],
#       dtype='|S2')

# %%
F3_vgsc = hier_group_vgsc == b'F3'
F3_paper = hier_group_paper == b'F3'

# %%
np.count_nonzero(F3_vgsc == F3_paper)
# Out:
# 1437

# %%
F4_vgsc = hier_group_vgsc == b'F4'
F4_paper = hier_group_paper == b'F4'

np.count_nonzero(F4_vgsc == F4_paper)
# Out:
# 1452

# %%
np.count_nonzero(F3_vgsc == F4_paper)
# Out:
# 1514

# %%
np.count_nonzero(F4_vgsc == F3_paper)
# Out:
# 1509

# %%
#OK that's a bit weird, these look completely different
#there's another .npy file in the phase 1 repo "special" 
#lets compare these three before looking at the median joining
hier_group_spesh = np.load('../data/vgsc_cluster_membership_special.npy')
np.unique(hier_group_spesh)
# Out:
# array([b'', b'F1', b'F2', b'F3', b'F4', b'F5', b'S1', b'S2', b'S3', b'S4',
#        b'S5'],
#       dtype='|S2')

# %%
hier_group_spesh.shape
# Out:
# (1530,)

# %%
F3_spesh = hier_group_spesh == b'F3'
F4_spesh = hier_group_spesh == b'F4'

# %%
np.count_nonzero(F4_paper == F4_spesh), np.count_nonzero(F3_paper == F3_spesh), np.count_nonzero(F4_paper == F3_spesh), np.count_nonzero(F3_paper == F4_spesh)
# Out:
# (1471, 1487, 1450, 1430)

# %% [markdown]
# ## check using a group we know is pretty stable

# %%
#check using something we know stays pretty constant however we cut it.
S3_paper = hier_group_paper == b'S3'
S3_spesh = hier_group_paper == b'S3'
S3_vgsc = hier_group_vgsc == b'S3'

# %%
#no difference between paper and special
np.count_nonzero(S3_paper == S3_spesh)
# Out:
# 1530

# %%
#but a fair bit of diff between the vgsc ms recreation of S3
np.count_nonzero(S3_paper == S3_vgsc), np.count_nonzero(S3_paper), np.count_nonzero(S3_vgsc)
# Out:
# (1516, 165, 165)
